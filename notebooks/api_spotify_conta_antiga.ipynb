# %% [markdown]
# # <font color='green'>Consumindo a API do Spotify</font>
#
# > **Serão utilizadas as bibliotecas:
# > Pandas, Matplotlib, Numpy, Seaborn, Spotipy e WordCloud**

# %%
# Podemos usar a exclamação quando o comando a ser executado é um comando do terminal
# !pip install spotipy
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/mchll/my_project_dir/my_project_env/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install wordcloud -q
# Out:
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/mchll/my_project_dir/my_project_env/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import spotipy
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
import seaborn as sns

sp = spotipy.Spotify()

sns.set_style("whitegrid")
 
from spotipy.oauth2 import SpotifyClientCredentials 
 
cid ='id do usuario'
secret = 'credenciais do usuario'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, 
client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
sp.trace=False 

playlists = sp.user_playlists('michellinhalira')
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/michellinhalira/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': "Scott Bradlee's Postmodern Jukebox, Norah Jones, Scott Bradlee and more",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1E366lrGn15vQg'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E366lrGn15vQg',
#    'id': '37i9dQZF1E366lrGn15vQg',
#    'images': [{'height': None,
#      'url': 'https://dailymix-images.scdn.co/v2/img/ab6761610000e5ebb6a4db349883e25e959e45ea/6/en/large',
#      'width': None}],
#    'name': 'Daily Mix 6',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
# ...

# %% [markdown]
# {'href': 'https://api.spotify.com/v1/users/michellinhalira/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'Stevie Ray Vaughan, John Mayall, Canned Heat and more',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1E366lrGn15vQg'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E366lrGn15vQg',
#    'id': '37i9dQZF1E366lrGn15vQg',
#    'images': [{'height': None,
#      'url': 'https://dailymix-images.scdn.co/v2/img/5bd95fbc961256c56560d838bd74d05be50701d4/6/en/large',
#      'width': None}],
#    'name': 'Daily Mix 6',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjcxMjI4NTEsMDAwMDAwMDAwZDZhYzdiZDdmNTliN2JjOTljYTFmOTU1NmM4NWYxNg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1E366lrGn15vQg/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1E366lrGn15vQg'},
#   {'collaborative': False,
#    'description': 'Collection of The Best Audiophile Relaxing Jazz Tracks by Don&#x27;s Tunes.  More Jazz &amp; Blues Playlists in my profile. Enjoy! https:&#x2F;&#x2F;www.youtube.com&#x2F;c&#x2F;DonsTunes. | donstunes.com',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3PjZgp31rg8Ddq7StV3SWH'},
#    'href': 'https://api.spotify.com/v1/playlists/3PjZgp31rg8Ddq7StV3SWH',
#    'id': '3PjZgp31rg8Ddq7StV3SWH',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb3867c13adce48f063af0e8fc',
#      'width': None}],
#    'name': "Relaxing Jazz Lounge | Don's Tunes",
#    'owner': {'display_name': "Don's Tunes",
#     'external_urls': {'spotify': 'https://open.spotify.com/user/dondraperstunes'},
#     'href': 'https://api.spotify.com/v1/users/dondraperstunes',
#     'id': 'dondraperstunes',
#     'type': 'user',
#     'uri': 'spotify:user:dondraperstunes'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'ODQ3LDJiNTBkNGM4ZmFjZTJiMDkzYWRkMzRjZmM5NGFkZmVmOWY3YzA2OTI=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3PjZgp31rg8Ddq7StV3SWH/tracks',
#     'total': 263},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3PjZgp31rg8Ddq7StV3SWH'},
#   {'collaborative': False,
#    'description': 'Blues - new and old - to accompany your drive.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9cTwPMorHcH'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9cTwPMorHcH',
#    'id': '37i9dQZF1DX9cTwPMorHcH',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003bfd38b1cff293590bc2f2e88',
#      'width': None}],
#    'name': 'Blues Drive',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYyNzQ3MTYzNCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9cTwPMorHcH/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX9cTwPMorHcH'},
#   {'collaborative': False,
#    'description': "Full of excitement, romance and bucket-loads of drama, Beethoven's symphonies are absolutely monumental. But don't just take our word for it; explore all of them right here, courtesy of the world's greatest orchestras.",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX62qlArsZbeu'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX62qlArsZbeu',
#    'id': '37i9dQZF1DX62qlArsZbeu',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f0000000386e8b838ae9532615aac5b90',
#      'width': None}],
#    'name': 'Beethoven Symphonies',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTU4MjcyNjc3OSwwMDAwMDAwNDAwMDAwMTcwODFkZTE0MmEwMDAwMDE3MDgxZGRkMDIy',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX62qlArsZbeu/tracks',
#     'total': 37},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX62qlArsZbeu'},
#   {'collaborative': False,
#    'description': 'A collection of Postmodern Jukebox jams :) ',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5rnfmkX6l2IqKg7AldxWsI'},
#    'href': 'https://api.spotify.com/v1/playlists/5rnfmkX6l2IqKg7AldxWsI',
#    'id': '5rnfmkX6l2IqKg7AldxWsI',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbcb8c37507dcd1ccd5c7dcd8a',
#      'width': None}],
#    'name': 'POSTMODERN JUKEBOX',
#    'owner': {'display_name': 'Zami Lee',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/zamisylee'},
#     'href': 'https://api.spotify.com/v1/users/zamisylee',
#     'id': 'zamisylee',
#     'type': 'user',
#     'uri': 'spotify:user:zamisylee'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTQ4LDY0YzFiYTNlNDc1ZGY0ZjU2ZTk5OWZlZTlhNGQwZjFkY2ZmOGExYjA=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5rnfmkX6l2IqKg7AldxWsI/tracks',
#     'total': 291},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5rnfmkX6l2IqKg7AldxWsI'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2owkcYxzCmjFF4rP7k9FDf'},
#    'href': 'https://api.spotify.com/v1/playlists/2owkcYxzCmjFF4rP7k9FDf',
#    'id': '2owkcYxzCmjFF4rP7k9FDf',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732ef73259916f5559222fc62aab67616d0000b273497e68476e7062b1bf5ea83fab67616d0000b2736a0eecc5d63cac39fe7132b6ab67616d0000b273dc04f429698834d0736ddb0a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732ef73259916f5559222fc62aab67616d0000b273497e68476e7062b1bf5ea83fab67616d0000b2736a0eecc5d63cac39fe7132b6ab67616d0000b273dc04f429698834d0736ddb0a',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732ef73259916f5559222fc62aab67616d0000b273497e68476e7062b1bf5ea83fab67616d0000b2736a0eecc5d63cac39fe7132b6ab67616d0000b273dc04f429698834d0736ddb0a',
#      'width': 60}],
#    'name': 'vamo acordar vamo acordar💙',
#    'owner': {'display_name': 'joaoarthurdrop',
#     'external_urls': {'spotify': 'https://open.spotify.com/user

#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb1f13686ce31fbc3e9c0a18e2',
#      'width': None}],
#    'name': 'Postmodern Jukebox Complete Discography (Vintage While You Work)',
#    'owner': {'display_name': "scott bradlee's postmodern jukebox",
#     'external_urls': {'spotify': 'https://open.spotify.com/user/postmodernjukebox'},
#     'href': 'https://api.spotify.com/v1/users/postmodernjukebox',
#     'id': 'postmodernjukebox',
#     'type': 'user',
#     'uri': 'spotify:user:postmodernjukebox'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTI5MSwyZmFkYTRiNWNjMDNlNGI1YjkwNjUxNWMxMDdjYjg4ODk4OTA2NWYw',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7csrlizJurpn6y0xenTwzu/tracks',
#     'total': 314},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7csrlizJurpn6y0xenTwzu'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/45FiaycSUiS62GhYZMSNDJ'},
#    'href': 'https://api.spotify.com/v1/playlists/45FiaycSUiS62GhYZMSNDJ',
#    'id': '45FiaycSUiS62GhYZMSNDJ',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732351d2408f27df6b29010f40ab67616d0000b2738020340f4ccc1b2fc4433d4bab67616d0000b273c014704fab22b477dafc0fa8ab67616d0000b273e82ba92d39bd71ff3f566879',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732351d2408f27df6b29010f40ab67616d0000b2738020340f4ccc1b2fc4433d4bab67616d0000b273c014704fab22b477dafc0fa8ab67616d0000b273e82ba92d39bd71ff3f566879',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732351d2408f27df6b29010f40ab67616d0000b2738020340f4ccc1b2fc4433d4bab67616d0000b273c014704fab22b477dafc0fa8ab67616d0000b273e82ba92d39bd71ff3f566879',
#      'width': 60}],
#    'name': 'Uns rap',
#    'owner': {'display_name': 'chell_lira',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/michellinhalira'},
#     'href': 'https://api.spotify.com/v1/users/michellinhalira',
#     'id': 'michellinhalira',
#     'type': 'user',
#     'uri': 'spotify:user:michellinhalira'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MzQ1LDgzNmJlNWY1YWIyNGQ4ZmUwY2FmMTdjMDBkYWVhYzMxNDhlZmJlZDc=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/45FiaycSUiS62GhYZMSNDJ/tracks',
#     'total': 385},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:45FiaycSUiS62GhYZMSNDJ'},
#   {'collaborative': False,
#    'description': 'Ouça lançamentos e destaques do indie brasileiro. Foto: Colomy',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZi7MSnECo7D'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZi7MSnECo7D',
#    'id': '37i9dQZF1DWZi7MSnECo7D',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003c431c7f77d5c0fffd3a198bc',
#      'width': None}],
#    'name': 'Indie Brasil',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYyNzAwOTM4MCwwMDAwMDFiYzAwMDAwMTdhZDE1MGVmMDcwMDAwMDE3YWNmZDAwMmZj',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZi7MSnECo7D/tracks',
#     'total': 99},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWZi7MSnECo7D'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 26}

# %% [markdown]
# ## Obtendo as músicas de 3 playlists diferentes da minha conta do spotify

# %% [markdown]
# Obtendo as músicas de 3 playlists diferentes da minha conta do spotify
#
# Esse endpoint retorna de 100 em 100 registros, por isso usei o atributo offset para obter os resultados paginados

# %%
# Utilizando a biblioteca Spotipy para extrair informações do usuário, passando o id da playlist
playlist = sp.user_playlist_tracks('michellinhalira', '37i9dQZF1E366lrGn15vQg', offset=0) 
songs1 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '5ZKQCyDColEdtatHcRqc67', offset=100) 
songs2 = playlist['items']

songs = songs1+songs2

# %%
#songs

# %%
playlist = sp.user_playlist_tracks('michellinhalira', '0PMcfaQBW5gHTuBaNw76sk', offset=0) 
songs1 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '5sfBOtBBoD9AtzCAUkKaOU', offset=100) 
songs2 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '37i9dQZF1DX11ghcIxjcjE', offset=200) 
songs3 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '7csrlizJurpn6y0xenTwzu', offset=300) 
songs4 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '2jKaZheOBzzGiHDRKhIvnC', offset=400) 
songs5 = playlist['items']

songs = songs1+songs2+songs3+songs4+songs5

# %%
playlist = sp.user_playlist_tracks('michellinhalira', '3bnvrpuf0BMGoMcuhSXZHz', offset=0) 
songs6 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '5tGjFJwKS5cKvdDK2kG5eR', offset=100) 
songs7 = playlist['items']

songs = songs+songs6+songs7

# %%
playlist = sp.user_playlist_tracks('michellinhalira', '3uClxwbwI0hDZNGnxiiZd7', offset=0) 
songs8 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '37i9dQZF1DX9cTwPMorHcH', offset=100) 
songs9 = playlist['items']

playlist = sp.user_playlist_tracks('michellinhalira', '45FiaycSUiS62GhYZMSNDJ', offset=100) 
songs10 = playlist['items']

# Unindo as informações de todas as playlists em uma só variável
songs = songs+songs8+songs9+songs10
songs

# Armazenando as playlists em um DataFrame
df = pd.DataFrame(songs)
df
# Out:
#                  added_at                                           added_by  \
# 0    2019-05-24T12:45:17Z  {'external_urls': {'spotify': 'https://open.sp...
# 1    2019-05-24T14:07:27Z  {'external_urls': {'spotify': 'https://open.sp...
# 2    2019-05-25T20:59:32Z  {'external_urls': {'spotify': 'https://open.sp...
# 3    2019-05-31T04:02:57Z  {'external_urls': {'spotify': 'https://open.sp...
# 4    2019-05-31T04:38:01Z  {'external_urls': {'spotify': 'https://open.sp...
# ..                    ...                                                ...
# 172  2019-02-05T14:12:11Z  {'external_urls': {'spotify': 'https://open.sp...
# 173  2019-02-05T14:12:15Z  {'external_urls': {'spotify': 'https://open.sp...
# 174  2019-03-05T17:36:35Z  {'external_urls': {'spotify': 'https://open.sp...
# 175  2019-03-05T18:03:37Z  {'external_urls': {'spotify': 'https://open.sp...
# 176  2019-03-07T05:10:21Z  {'external_urls': {'spotify': 'https://open.sp...
#
#      is_local primary_color  \
# ...

# %% [markdown]
# ## Obtendo dados de artistas, albuns e músicas do Spotify

# %% [markdown]
# Montamos 2 Dataframes, o primeiro com infomações sobre a música e seus respectivos artista e álbum.
#
# No segundo, obtemos informações específicas do artista, para obter seus gêneros músicais e a popularidade no spotify
#
# Ao todo são 750 músicas de 303 artistas dentro das 3 playlists selecionadas

# %%
musics_info = []
artists = []
for i, item in enumerate(songs):
    track = item['track']
    added_at = item['added_at']
    try:
      artist = sp.artist(track['artists'][0]['id'])
    except AttributeError:
       print('Erro ao obter dados do artista')
    musics_info.append((track['artists'][0]['name'], track['name'], track['album']['name'], added_at, track['id']))
    artists.append((track['artists'][0]['name'], track['artists'][0]['id'], artist['genres'], artist['popularity'] ))

#print(artists)

pd.set_option('display.max_rows', 50)
df_musics = pd.DataFrame(musics_info, columns=('Artists', 'Name', 'Album', 'Added_At', 'Id'))
print(len(df_musics['Name']))
# Out:
# Erro ao obter dados do artista
# 177

# %%
df_artists = pd.DataFrame(artists, columns=('Name', 'Id', 'Genres', 'Popularity'))
df_artists
# Out:
#                   Name                      Id  \
# 0    Charlie Brown Jr.  1on7ZQ2pvgeQF4vmIA09x5
# 1    Charlie Brown Jr.  1on7ZQ2pvgeQF4vmIA09x5
# 2    Charlie Brown Jr.  1on7ZQ2pvgeQF4vmIA09x5
# 3    Charlie Brown Jr.  1on7ZQ2pvgeQF4vmIA09x5
# 4    Charlie Brown Jr.  1on7ZQ2pvgeQF4vmIA09x5
# ..                 ...                     ...
# 172            Raillow  0sidBbuq2OCR7mtHiSIfCN
# 173         Filipe Ret  7gJN8W0589FisSYJS17K54
# 174    Atentado Napalm  3zRsSdPeUYBcjWXlX2HXVW
# 175             Scooby  5hPR4hVEcnsIv4A2OAhNAd
# 176            MMoneis  24OpSz4pEAeaGPKFfOLjNp
#
#                                                 Genres  Popularity
# 0    [brazilian rock, hard rock brasileiro, rock al...          77
# 1    [brazilian rock, hard rock brasileiro, rock al...          77
# 2    [brazilian rock, hard rock brasileiro, rock al...          77
# 3    [brazilian rock, hard rock brasileiro, rock al...          77
# ...

# %%
len(df_artists['Name'].unique().tolist()) # tolist(): retorna uma lista de valores
# Out:
# 65

# %% [markdown]
# Montando Dataframe de gêneros musicais dentre as bandas das playlists

# %%
genres = []
for index, row in df_artists.iterrows():  # iterrows(): faz a iteração nas linhas do DataFrame como pares (índice, Series). 
    for i, item in enumerate(row['Genres']): # enumerate(): A função enumerate() retorna uma tupla de dois elementos a cada iteração: um número sequencial e um item da sequência correspondente.
      genres.append(item)

df_genres = pd.DataFrame(genres, columns =['Count Genres'])
df_genres
# Out:
#                  Count Genres
# 0                      pagode
# 1                 pagode novo
# 2               sertanejo pop
# 3                      pagode
# 4                 pagode novo
# ..                        ...
# 507         brazilian hip hop
# 508       rap nacional antigo
# 509  afrofuturismo brasileiro
# 510         brazilian hip hop
# 511           trap brasileiro
#
# [512 rows x 1 columns]

# %%
# Listando a quantidade de reprodução de determinado gênero musical
df_genres['Count Genres'].value_counts()
# Out:
# brazilian hip hop              84
# brazilian rock                 48
# hard rock brasileiro           35
# rock alternativo brasileiro    33
# rock nacional brasileiro       33
# pagode                         24
# pagode novo                    15
# rap nacional antigo            14
# brazilian reggae               14
# rap df                         13
# swing                          13
# trap brasileiro                13
# funk ostentacao                12
# sertanejo pop                  12
# afrofuturismo brasileiro       10
# manguebeat                     10
# mpb                             9
# velha guarda                    9
# samba                           9
# boom bap brasileiro             8
# bossa nova                      8
# latin afrobeat                  7
# afrobeat brasileiro             7
# pop rap brasileiro              6
# funk carioca                    6
# rap mineiro                     6
# sertanejo universitario         6
# ...

# %%
df_musics['Artists'].value_counts().head(20)
# Out:
# Charlie Brown Jr.                     33
# Scott Bradlee's Postmodern Jukebox    13
# Dilsinho                              10
# Criolo                                 7
# Um Barril de Rap                       7
# BK                                     6
# Baden Powell                           5
# Síntese                                5
# Djonga                                 5
# Froid                                  5
# MV Bill                                4
# Marcelo D2                             4
# Turma do Pagode                        4
# Pentagono                              3
# Haikaiss                               3
# Baco Exu do Blues                      3
# Ferrugem                               3
# Cartola                                3
# Racionais MC's                         2
# Xamã                                   2
# Name: Artists, dtype: int64

# %%
df_musics['Name'].value_counts().sum()
# Out:
# 177

# %%
# Exibindo os 20 álbuns mais reproduzidos
df_musics['Album'].value_counts().head(20)
# Out:
# Terra do Nunca (Ao Vivo)                            7
# La Familia 013                                      6
# The New Classics (Recorded Live!)                   6
# Castelos & Ruínas                                   5
# 2ª Via                                              5
# Imunidade Musical                                   4
# Acústico (Ao Vivo)                                  4
# Camisa 10 joga bola até na chuva                    4
# Trilha para o Desencanto da Ilusão, Vol. 1: Amem    4
# Heresia                                             3
# Os Afro-Sambas                                      3
# Ainda Há Tempo                                      3
# Prazer, eu sou Ferrugem (Ao vivo)                   3
# Tamo Ai Na Atividade                                3
# Misturadin (Ao Vivo)                                2
# Natural                                             2
# O Cara Certo                                        2
# ...

# %%
# Contando quantos albuns estão representados no DataFrame "df_musics"
df_musics['Album'].value_counts().sum()
# Out:
# 177

# %%
# Checando se há dados nulos
df_genres.isnull().value_counts()
# Out:
# Count Genres
# False           512
# dtype: int64

# %%
df_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Count Genres  512 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %% [markdown]
# ## 30 artistas mais presentes

# %%
# Separando informações que queremos incluir no gráfico
names = list(df_musics['Artists'].value_counts().keys())[:30]
values = list(df_musics['Artists'].value_counts())[:30]

# Definindo detalhes da imagem e plotando
fig, axs = plt.subplots(figsize=(35,15))
axs.bar(names, values)
plt.xticks(rotation=90, fontsize=25);
fig.suptitle('Bandas', fontsize=25)
# Out:
# Text(0.5, 0.98, 'Bandas')

# %% [markdown]
# ## 10 Bandas mais presentes

# %%
# Separando informações que queremos incluir no gráfico
names = list(df_musics['Artists'].value_counts().head(10).keys())
values = list(df_musics['Artists'].value_counts().head(10))

# Definindo detalhes da imagem e plotando
fig, axs = plt.subplots(figsize=(25,12))
axs.bar(names, values)
plt.xticks(rotation=90, fontsize=25);
fig.suptitle('Bandas', fontsize=25);

# %% [markdown]
# ## 10 Albums mais presentes

# %%
# Separando informações que queremos incluir no gráfico
names = list(df_musics['Album'].value_counts().head(10).keys())
values = list(df_musics['Album'].value_counts().head(10))

# Definindo detalhes da imagem e plotando
fig, axs = plt.subplots(figsize=(12,7))
axs.bar(names, values)
plt.xticks(rotation=90, fontsize=15);
fig.suptitle('Albuns', fontsize=15);

# %% [markdown]
# ## 30 gêneros musicais mais presentes

# %%
# Separando informações que queremos incluir no gráfico
names = list(df_genres['Count Genres'].value_counts().keys())[:30]
values = list(df_genres['Count Genres'].value_counts())[:30]

# Definindo detalhes da imagem e plotando
fig, axs = plt.subplots(figsize=(35,15))
axs.bar(names, values)
plt.xticks(rotation=90, fontsize=20);
fig.suptitle('Generos', fontsize=25);

# %% [markdown]
# ## 20 gêneros musicais mais presentes

# %%
# Separando informações que queremos incluir no gráfico
names = list(df_genres['Count Genres'].value_counts().head(20).keys())
values = list(df_genres['Count Genres'].value_counts().head(20))

# Definindo detalhes da imagem e plotando
fig, axs = plt.subplots(figsize=(10,8))
axs.bar(names, values)
plt.xticks(rotation=90);
fig.suptitle('Generos', fontsize=15);
fig.patch.set_facecolor('xkcd:mint green')

# %% [markdown]
# ## Bandas mais populares no Spotify

# %%
# Ordenando os dados da coluna "Popularity", em ordem decrescente
df_artists = df_artists.sort_values(by=['Popularity'], ascending=False)

# Separando informações que queremos incluir no gráfico
names = df_artists['Name'].head(132)
values =  df_artists['Popularity'].head(132)

# Definindo detalhes da imagem e o conteúdo de cada eixo do gráfico
fig, axs = plt.subplots(figsize=(14,8))
axs.bar(names, values)
plt.xticks(rotation=90);
fig.suptitle('Popularidade', fontsize=18);
fig.patch.set_facecolor('xkcd:mint green')

# %% [markdown]
# ## Wordcloud montada com as bandas mais presentes nas playlists selecionadas

# %%
# Inserindo cada palavra da coluna "Artists" do DataFrame "musics" na variável all_summary
all_summary = " ".join(s for s in df_musics['Artists'])

# Imprimindo na tela a quantidade de palavras
print(f"Quantidade de Palavras: {len(all_summary)}")
# Out:
# Quantidade de Palavras: 2353

# %%
# Gerando uma wordcloud
wordcloud = WordCloud(background_color="black",
                      width=1600, height=800, colormap="Set2", collocations=False).generate(all_summary)

# Definindo detalhes da imagem
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear') # 'interpolation = bilinear' é usado para fazer a imagem parecer mais suave. 
ax.set_axis_off()

# Mostrando a imagem final
plt.imshow(wordcloud)
#wordcloud.to_file("bandas_spotify_michelle.png");

# %%
#df_genres.to_csv('./dados_tratados/genres.csv', index = None)

# %%
#df_artists.to_csv('./dados_tratados/artists.csv', index = None)

# %% [markdown]
# ### O código deste consumo de API é baseado no tutorial do:
# #### https://github.com/kaiovalente/ds-spotify/blob/master/Kaio_Valente_Spotify.ipynb

# %% [markdown]
# ## Fim

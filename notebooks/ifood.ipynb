# %% [markdown]
# # <font color='red'>Tratando os dados do Ifood</font>

# %% [markdown]
# ### <font color='red'>Instalando as bibliotecas:</font>
#
# Matplotlib, Numpy, Pandas, Seaborn e Wordcloud.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (1.21.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from pandas) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: scipy>=1.0 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: pandas>=0.23 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from seaborn) (1.3.0)
# Requirement already satisfied: matplotlib>=2.2 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

sns.set_context("talk", font_scale=1)
sns.set_style("darkgrid")
sns.set_palette('tab10')
sns.set_color_codes()

# %% [markdown]
# ## <font color='red'>Compreendendo os dados de cada arquivo da base</font>

# %% [markdown]
# <font color='red'>__enderecos.csv:__</font>
# ```
#     id_usuario
#     tipo: indica se é um endereço residencial, de trabalho, etc.
#     logradouro
#     numero
#     complemento
#     bairro
#     cidade
#     estado
#     pais
#     data_registro: data que um endereço foi cadastrado na conta do usuário.
# ```
#
# <font color='red'>__pedidos.csv__</font>
# ```
#     id_usuario
#     id_pedido
#     restaurante
#     valor
#     status: concluído ou cancelado
#     data_registro
#     data_pedido
# ```
#
# <font color='red'>__usuarios.csv__</font>
# ```
#     id_usuario
#     nome
#     cpf
#     email
#     telefone
#     data_registro: data que o usuário de cadastrou na plataforma
# ```

# %% [markdown]
# ## <font color='red'>Importando os dados</font>

# %%
# Importando dados de endereços cadastrados 
df_enderecos = pd.read_csv('./dados/ifood/enderecos.csv')

df_enderecos.head(5)
# Out:
#                              id_usuario      tipo  \
# 0  d896783a-bf28-4ccf-a881-c0a48cf32e6b       NaN
# 1  d896783a-bf28-4ccf-a881-c0a48cf32e6b       NaN
# 2  d896783a-bf28-4ccf-a881-c0a48cf32e6b       NaN
# 3  d896783a-bf28-4ccf-a881-c0a48cf32e6b  Trabalho
# 4  d896783a-bf28-4ccf-a881-c0a48cf32e6b       NaN
#
#                       logradouro  numero                        complemento  \
# 0             R SETE DE SETEMBRO     365                               1702
# 1  R. LUIZ CÂMARA DE ALBUQUERQUE      16  CASA - DUPLEX VERDE LADO ESQUERDO
# 2                     R. GRAMADO     136                   BLOCO 3 - AP 604
# 3         AV REPUBLICA DO LIBANO     251                                NaN
# 4                     R. PIO XII     395                               CASA
#
#              bairro                   cidade estado pais data_registro
# 0         BOA VISTA                   RECIFE     PE   BR    2018-10-12
# 1      SANTO ALEIXO  JABOATÃO DOS GUARARAPES     PE   BR    2020-07-20
# 2  BARRA DE JANGADA  JABOATÃO DOS GUARARAPES     PE   BR    2019-08-25
# 3              PINA                   RECIFE     PE   BR    2018-07-30
# 4     CAJUEIRO SECO  JABOATÃO DOS GUARARAPES     PE   BR    2019-03-04

# %%
# Importando dados de pedidos 
df_pedidos = pd.read_csv('./dados/ifood/pedidos.csv')

df_pedidos.head(5)
# Out:
#                              id_usuario   id_pedido              restaurante  \
# 0  d896783a-bf28-4ccf-a881-c0a48cf32e6b  1612462410       Recanto Nordestino
# 1  d896783a-bf28-4ccf-a881-c0a48cf32e6b   401782309         Imperio Da China
# 2  d896783a-bf28-4ccf-a881-c0a48cf32e6b   401786706               Chef Arabe
# 3  d896783a-bf28-4ccf-a881-c0a48cf32e6b  1547446858              Della Mamma
# 4  d896783a-bf28-4ccf-a881-c0a48cf32e6b   314176243  Domino's Pizza - Gracas
#
#    valor     status data_registro data_pedido
# 0   71.9  CONCLUDED    2018-07-30  2020-03-09
# 1   36.9  CONCLUDED    2018-07-30  2019-01-12
# 2   34.9  CONCLUDED    2018-07-30  2019-01-12
# 3   50.0  CONCLUDED    2018-07-30  2020-02-19
# 4   66.9  CANCELLED    2018-07-30  2018-10-13

# %%
# Importando dados de usuário
df_usuario = pd.read_csv('./dados/ifood/usuarios.csv')

df_usuario
# Out:
#                              id_usuario            nome  cpf  \
# 0  d896783a-bf28-4ccf-a881-c0a48cf32e6b  Michelle Lira   NaN
#
#                   email      telefone data_registro
# 0  MCHLL.LIRA@GMAIL.COM  81 999337749    2018-07-30

# %% [markdown]
# ## <font color='red'>Verificando o tamanho dos DataFrames</font>

# %%
# Verificando o tamanho do dataset
df_enderecos.shape[0]
# Out:
# 6

# %%
# Verificando o tamanho do dataset
df_pedidos.shape[0]
# Out:
# 51

# %% [markdown]
# ## <font color='red'>Verificando se há dados nulos</font>

# %%
# 01 - Endereços
df_enderecos.isnull().sum()
# Out:
# id_usuario       0
# tipo             5
# logradouro       0
# numero           0
# complemento      1
# bairro           0
# cidade           0
# estado           0
# pais             0
# data_registro    0
# dtype: int64

# %%
# 02 - Pedidos
df_pedidos.isnull().sum()
# Out:
# id_usuario       0
# id_pedido        0
# restaurante      0
# valor            0
# status           0
# data_registro    0
# data_pedido      0
# dtype: int64

# %% [markdown]
# ## <font color='red'>Detalhes dos DataFrames</font>

# %%
df_enderecos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     6 non-null      object
#  1   tipo           1 non-null      object
#  2   logradouro     6 non-null      object
#  3   numero         6 non-null      int64
#  4   complemento    5 non-null      object
#  5   bairro         6 non-null      object
#  6   cidade         6 non-null      object
#  7   estado         6 non-null      object
#  8   pais           6 non-null      object
#  9   data_registro  6 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 608.0+ bytes

# %%
df_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     51 non-null     object
#  1   id_pedido      51 non-null     int64
#  2   restaurante    51 non-null     object
#  3   valor          51 non-null     float64
#  4   status         51 non-null     object
#  5   data_registro  51 non-null     object
#  6   data_pedido    51 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
df_usuario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     1 non-null      object
#  1   nome           1 non-null      object
#  2   cpf            0 non-null      float64
#  3   email          1 non-null      object
#  4   telefone       1 non-null      object
#  5   data_registro  1 non-null      object
# dtypes: float64(1), object(5)
# memory usage: 176.0+ bytes

# %% [markdown]
# ## <font color='red'>Convertendo os dados</font>

# %% [markdown]
# ### <font color='red'>No DataFrame "Endereços"</font>
#
# >A coluna data_registro está com o tipo object, ou seja, string -> Quero o formato datetime

# %%
# Convertendo data_registro de string para datetime
df_enderecos['data_registro'] = pd.to_datetime(df_enderecos['data_registro'])

# %%
# 01 - Endereços cadastrados
df_enderecos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     6 non-null      object
#  1   tipo           1 non-null      object
#  2   logradouro     6 non-null      object
#  3   numero         6 non-null      int64
#  4   complemento    5 non-null      object
#  5   bairro         6 non-null      object
#  6   cidade         6 non-null      object
#  7   estado         6 non-null      object
#  8   pais           6 non-null      object
#  9   data_registro  6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 608.0+ bytes

# %%
# Exibindo o dtypes com uma melhor formatação, como um DataFrame
pd.DataFrame(df_enderecos.dtypes, columns=['Tipos de dados'])
# Out:
#                Tipos de dados
# id_usuario             object
# tipo                   object
# logradouro             object
# numero                  int64
# complemento            object
# bairro                 object
# cidade                 object
# estado                 object
# pais                   object
# data_registro  datetime64[ns]

# %% [markdown]
# ### <font color='red'>No DataFrame "Pedidos"</font>
#
# >A coluna data_registro está com o tipo object, ou seja, string -> Quero o formato datetime
# >A coluna data_pedido está com o tipo object, ou seja, string -> Quero o formato datetime

# %%
# Convertendo data_registro e data_pedido de string para datetime
df_pedidos['data_registro'] = pd.to_datetime(df_pedidos['data_registro'])

# %%
df_pedidos['data_pedido'] = pd.to_datetime(df_pedidos['data_pedido'])

# %%
# 02 - Pedidos
df_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     51 non-null     object
#  1   id_pedido      51 non-null     int64
#  2   restaurante    51 non-null     object
#  3   valor          51 non-null     float64
#  4   status         51 non-null     object
#  5   data_registro  51 non-null     datetime64[ns]
#  6   data_pedido    51 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 2.9+ KB

# %%
# Exibindo o dtypes com uma melhor formatação, como um DataFrame
pd.DataFrame(df_pedidos.dtypes, columns=['Tipos de dados'])
# Out:
#                Tipos de dados
# id_usuario             object
# id_pedido               int64
# restaurante            object
# valor                 float64
# status                 object
# data_registro  datetime64[ns]
# data_pedido    datetime64[ns]

# %% [markdown]
# ### <font color='red'>No DataFrame: "Usuários"</font>
#
# >A coluna data_registro está com o tipo object, ou seja, string -> Quero o formato datetime

# %%
# Convertendo data_registro de string para datetime
df_usuario['data_registro'] = pd.to_datetime(df_usuario['data_registro'])

# %%
# 03 - Usuário
df_usuario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_usuario     1 non-null      object
#  1   nome           1 non-null      object
#  2   cpf            0 non-null      float64
#  3   email          1 non-null      object
#  4   telefone       1 non-null      object
#  5   data_registro  1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 176.0+ bytes

# %%
pd.DataFrame(df_pedidos['restaurante'].unique(), columns = ['Restaurantes'])
# Out:
#                                Restaurantes
# 0                        Recanto Nordestino
# 1                          Imperio Da China
# 2                                Chef Arabe
# 3                               Della Mamma
# 4                   Domino's Pizza - Gracas
# 5                          Cabuloso Burguer
# 6                             Super Sanduba
# 7                             Emporio Prime
# 8                             Recanto Prime
# 9                                K Delivery
# 10                       Pizzaria Boa Massa
# 11  Coliseu Delivery Hamburgueria Artesanal
# 12                       Big Baita Candeias
# 13                    Big Dog's - Especiais
# 14                            Bar Do Matuto
# 15                             Doceria Real
# 16                          Dashi Comedoria
# 17                             Los Gautchos
# 18                        Lampiao Comedoria
# 19                   China Burguer Oriental
# 20                               Big Spetto
# 21                               Maya Kebab
# 22                         Recanto Da Barra
# 23                                 Sr Dogao
# 24             Escalante S Tex Mex Candeias
# 25                          Vic S Best Food
# 26                                May Sushi
# 27                       Creperia El Shaday
# 28                  Jolu Comedoria Japonesa
# 29                        Sr Dogao Dogueria
# 30                     Deposito Altas Horas
# 31                           Brownie Do Jad
# 32                            Valenca Sushi
# 33                            China Burguer
# 34             Moda Nostra Pizza - Candeias
# 35                        Delicia Do Pastel
# 36         Dona Do Sabor Lanches E Salgados
# 37                          Crepe's Burguer
# 38                        Camarao Temakeria

# %%
df_pedidos['restaurante'].value_counts().head(40)
# Out:
# May Sushi                                  3
# Recanto Prime                              3
# Coliseu Delivery Hamburgueria Artesanal    3
# Recanto Nordestino                         2
# Escalante S Tex Mex Candeias               2
# Della Mamma                                2
# Creperia El Shaday                         2
# Bar Do Matuto                              2
# Recanto Da Barra                           2
# Sr Dogao Dogueria                          1
# Vic S Best Food                            1
# Jolu Comedoria Japonesa                    1
# Brownie Do Jad                             1
# Deposito Altas Horas                       1
# Valenca Sushi                              1
# China Burguer                              1
# Moda Nostra Pizza - Candeias               1
# Delicia Do Pastel                          1
# Dona Do Sabor Lanches E Salgados           1
# Crepe's Burguer                            1
# Sr Dogao                                   1
# China Burguer Oriental                     1
# Maya Kebab                                 1
# Pizzaria Boa Massa                         1
# Chef Arabe                                 1
# Domino's Pizza - Gracas                    1
# Cabuloso Burguer                           1
# Super Sanduba                              1
# Emporio Prime                              1
# K Delivery                                 1
# Big Baita Candeias                         1
# Big Spetto                                 1
# Big Dog's - Especiais                      1
# Doceria Real                               1
# Dashi Comedoria                            1
# Los Gautchos                               1
# Lampiao Comedoria                          1
# Imperio Da China                           1
# Camarao Temakeria                          1
# Name: restaurante, dtype: int64

# %%
pd.DataFrame(df_pedidos['id_pedido'])
# Out:
#      id_pedido
# 0   1612462410
# 1    401782309
# 2    401786706
# 3   1547446858
# 4    314176243
# 5    314184305
# 6   1240294990
# 7    887148596
# 8   1279667192
# 9   1596523044
# 10  1468845484
# 11  1468855657
# 12  1527517293
# 13  1457208336
# 14  1619157648
# 15  1619561668
# 16  2081016937
# 17  1976714127
# 18  1203102680
# 19  1026437160
# 20  2828510782
# 21  1377243313
# 22  1377259908
# 23  1644091970
# 24  1826467801
# 25  1911956768
# 26  1487255327
# 27  3193269790
# 28  1600978319
# 29  2824841576
# 30  1585875680
# 31  1649545258
# 32  1649532300
# 33  1562017174
# 34  1507813764
# 35  1507801787
# 36  2086368104
# 37  1137754549
# 38  1819443476
# 39  1819466498
# 40  3093981183
# 41  3115060399
# 42  3115077173
# 43  3215237544
# 44  1275587648
# 45  1275548185
# 46  1982922109
# 47  4043788140
# 48  3155207197
# 49  3166042335
# 50  3104002710

# %%
df_enderecos['logradouro'].value_counts().head(20)
# Out:
# R SETE DE SETEMBRO               1
# R. LUIZ CÂMARA DE ALBUQUERQUE    1
# R. GRAMADO                       1
# AV REPUBLICA DO LIBANO           1
# R. PIO XII                       1
# R SERRA TALHADA                  1
# Name: logradouro, dtype: int64

# %%
# Total gasto em pedidos
df_pedidos['valor'].sum()
# Out:
# 2244.57

# %%
# Configurações dos gráficos
plt.rcParams['figure.figsize'] = (15,10)
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['font.size'] = 15 
plt.rcParams['axes.titlesize'] = 20

# Identificando outliers nos valores de compras
sns.boxplot(x = df_pedidos['valor'], color='red')
plt.show()

# %% [markdown]
# ## Nuvem de palavras
#
# Criei uma wordcloud, com os nomes dos restaurantes nos quais fiz pedido.
# Os restaurantes com mais pedidos tem mais visibilidade.

# %%
# Percorrendo a variável artistName para armazenar na variável músicas
restaurantes = " ".join(s for s in df_pedidos['restaurante'])

# Imprimindo a quantidade de palavras
print(f"Quantidade de Palavras: {len(restaurantes)}")
# Out:
# Quantidade de Palavras: 929

# %%
# Gerando uma nuvem de palavras
wordcloud = WordCloud(background_color="white",
                      width=2000, height=1000, random_state=1, contour_color="white", colormap="Set1", collocations=False).generate(restaurantes)

# Definindo detalhes da imagem
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud)
#wordcloud.to_file("restaurantes_ifood_michelle.png");

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /home/mchll/my_project_dir/my_project_env/lib/python3.8/site-packages (8.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from os import path

d = path.dirname(__file__) if "/home/mchll/my_project_dir/my_project_env/projeto_mod_5/share.jpg" in locals() else os.getcwd()
alice_mask = np.array(Image.open(path.join(d, "share.jpg")))

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='black', colormap='Set1').generate(restaurantes)


# store to file
wc.to_file(path.join(d, "alice.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Salvando os DataFrames com dados tratados

# %%
# 01 - Salvando o arquivo com os endereços
df_enderecos.to_csv('./dados_tratados/ifood/enderecos.csv', index = None)

# %%
# 02 - Salvando os dados dos pedidos 
df_pedidos.to_csv('./dados_tratados/ifood/pedidos.csv', index = None)

# %%
# 03 - Salvando os dados de usuário
df_usuario.to_csv('./dados_tratados/ifood/usuarios.csv', index = None)

# %% [markdown]
# ## Fim
